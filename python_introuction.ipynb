# %% [markdown]
# <a href="https://colab.research.google.com/github/Aimantech/Aimantech.github.io/blob/master/python_introuction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list and tupils data structures
animals = ['cat', 'dog']
animals
# Out:
# ['cat', 'dog']

# %%
animals.append('mat')
animals
# Out:
# ['cat', 'dog', 'mat', 'mat', 'mat']

# %%
animals[2] = 'bat'
animals
# Out:
# ['cat', 'dog', 'bat', 'mat', 'mat']

# %%
point =(3,7)
point
# Out:
# (3, 7)

# %%
point[1]
# Out:
# 7

# %%
point[1] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ff5b3ba61537> in <module>()
# ----> 1 point[1] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
#numpy arrays
import numpy as np

a = np.arange(1,10)
print(a)
#np.arange(5)
#np.arange(2.1, 5.4, 0.1)
#np.arange(0, 10, 1.5)
b = np.linspace(0, 10, 7)
print(b)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 0.          1.66666667  3.33333333  5.          6.66666667  8.33333333
#  10.        ]

# %%
#stings 
s = '123'
pie = '3.141592653589' 
x = int(s) + 1 
y = float(pie) + 1
#z_bad = int(s) + int(pie)
z_good = int(s) + int(float(pie))
print (z_good)
# Out:
# 126

# %%
#list function , string cannot be modified as list
list('Hello')
x = [1, 1, 1]
x[1] = 2
x [1, 2, 1]

# %%
#deleting elements from list
ames = ['Alice', 'Beth', 'Cecil', 'Dee-Dee', 'Earl']
del names[2]
names ['Alice', 'Beth', 'Dee-Dee', 'Earl']

# %%
#assigning to slice
#Slicing is a very powerful feature, and it is made even more powerful by the fact that you can assign to slices:
name = list('Perl')
print(name)
#name ['P', 'e', 'r', 'l']
name[2:] = list('ar')
#name ['P', 'e', 'a', 'r']
# Out:
# ['P', 'e', 'r', 'l']

# %%
#append at the end of list
lst = [1, 2, 3]
lst.append(4)
#lst [1, 2, 3, 4]

# %%
#insert object
numbers = [1, 2, 3, 5, 6, 7]
numbers.insert(3, 'four')

# %%
#pop , will remove last frm list by default
x = [1, 2, 3]
x.pop()

x
[1, 2]
x.pop(0)
1
>>> x
[2]
#Using pop, you can implement a common data structure called a stack.
#A stack like this works just like a stack of plates. You can put plates on
#top, and you can remove plates from the top. The last one you put into
#the stack is the first one to be removed. (This principle is called Last-In,
#First-Out, or LIFO.)

# %%
#remove
x = ['to', 'be', 'or', 'not', 'to', 'be']
x.remove('be')

# %%
#for loop
for x in range(5):
print (x)
for x in range(3, 6):
print(x)
# Prints out 3,5,7
for x in range(3, 8, 2):
print(x)
# Out:
#   File "<ipython-input-24-5ba5d4a70c44>", line 2
#     print(x)
#         ^
# IndentationError: expected an indented block

# %%
#time on small range
import time
#use time.time() on Linux
start = time.clock()
for x in range(1000):
pass
stop = time.clock()
print stop-start
start = time.clock()
for x in xrange(1000):
pass
stop = time.clock()
print stop-start

# %%
#if else statement

import numpy as np
from math import *
# If statement
x=float(input('Value: '))
if x==10:
print('X is a 10')
elif x > 10:
print ('X is larger than 10')
else :
print('X is less than 10...')
print(x)
########################
value = int(input("Please enter an integer in the range 0...5: "))
print('Program starts..............')
if value < 0 :
print("Too small")
elif value == 0:
print("zero")
elif value == 1:
print("one")
elif value == 2:
print("two")
elif value == 3:
print("three")
elif value == 4:
print("four")
elif value == 5:
print("five")
else:
print("Too large")
print("Program complete.......................")

# %%
#while 
# Prints out 0,1,2,3,4 and then it prints "count value reached 5"
import numpy as np
count=0
while(count<5):
print(count)
count +=1
else:
print("count value reached %d" %(count))
# Prints out 1,2,3,4
for i in range(1, 10):
if(i%5==0):
### % is the remainder
break
print(i)
else:
print("this is not printed because for loop is terminated because of break "
"but not due to fail in condition")

# %%
#define and calling function
import numpy as np
def plus(a,b):
sum = a + b
return sum
def mult (a,b):
mul=a*b
return mul
def hsqr (a,b):
dh=a*a+b*b+2*a*b
return dh

# %%
import numpy as np
from sknfun import plus,mult,hsqr
a=float(input('a:'))
b=float(input('b:'))
sd=plus(a,b)
print('Sum of two numbers...............')
print(sd)
df=mult (a,b)
print('Multiplication of two numbers...............')
print(df)
gh=hsqr(a,b)
print('Square of two numbers...............')
print(gh)

# %%
#first coding pg
import numpy as np
from math import *
'''
This Python file created by Dr. Santosh Kumar Nanda
Date: 20/2/2018
Version 1.1
'''
###### For hexadecimal value
bb=hex(1024)
###### For binary value
vv=bin(1024)
print('..............Hexadecimal value............')
print(bb)
print('..............Binary value............')
print(vv)
####### Addition ###########
a=float(input('a: '))
b=float(input('b: '))
c=a+b
print('..............Addition of two value............')
print(c)
dd=a-b
print('..............Substraction of two value............')
print(dd)
vs=sqrt(a)
print('............Sqaure Root of a value..........')
print(vs)
########## Import numpy as mathematic operation ########
from numpy import sqrt, exp
vz=sqrt(2)
vd=exp(3)
print('Square and expontetial from numpy.........')
print('square root.........')
print(vz)
print('expontial.........')
print(vd)

# %%
#extract data from excel ,visualaisation

import numpy as np
import matplotlib.pyplot as plt
from openpyxl import load_workbook

wb = load_workbook('skn_demo.xlsx')
sheet_1=wb.get_sheet_by_name('Sheet1')
xx=np.zeros(sheet_1.max_row)
yy=np.zeros(sheet_1.max_row)
zz=np.zeros(sheet_1.max_row)
for i in range(0, sheet_1.max_row):
xx[i] =sheet_1.cell(row=i + 1, column=1).value
yy[i] =sheet_1.cell(row=i + 1, column=2).value
######## Data Visulaization ###############
plt.figure(5)
plt.plot(xx, yy, label='Data-1')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plot')
plt.legend(loc='best', fontsize='small')
plt.savefig('Xl_demo.png')
plt.show()

# %%
##create excel to store the data

import openpyxl
wb=openpyxl.Workbook()
sheet=wb.get_active_sheet()
sheet.title='Sheet#1'
######################
xb=np.linspace(1,10,10)
yb=xb*xb
########## Add title
sheet.cell(row=1, column=1).value='X values'
sheet.cell(row=1, column=2).value='Y values'
######
for i in range (0,len(xb)):
sheet.cell(row=i+2, column=1).value=xb[i]
sheet.cell(row=i + 2, column=2).value = yb[i]
#########
wb.save('write_simple.xlsx')

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2* np.pi *t)
plt.figure(1)
plt.plot(t, s, color="green", linewidth=1.5, label='Sine-Function')
plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('Plot of Sine-Function')
plt.grid(True)
plt.axis([np.min(t),np.max(t),np.min(s),np.max(s)])
plt.legend (loc='best')
plt.savefig("test1.png")
plt.show()

# %%
# simple_plot.py [get code]
import numpy as np, matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2* np.pi *t)
s1 = 1 + np.cos(2* np.pi *t)
plt.figure(1)
plt.plot(t, s, color="green", linewidth=1.5, label='Sine-Function')
plt.plot(t, s1, color="red", linewidth=1.5, label='Cosine-Function')
plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('Plot of Sine-Function')
plt.grid(True)
plt.axis([np.min(t),np.max(t),np.min(s),np.max(s)])
plt.legend (loc='best')
#plt.savefig("test1.pdf")
plt.savefig("test2.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g')
#plt.savefig("test3.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):
    return np.exp(-t) * np.cos(2* np.pi *t)
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.figure(2)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(212)
plt.plot(t2, np.cos(2* np.pi *t2), 'r--')
plt.savefig("test4.png")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
fig = plt.figure(3)
ax = fig.gca(projection='3d')
# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
linewidth=0, antialiased=False)
# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
#plt.savefig("test5.png")
plt.show()
